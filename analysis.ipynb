# %% [markdown]
# # Litter Detection — Analysis Notebook
#
# 1. Inspect training data (images + masks)
# 2. Review MLflow experiment history
# 3. Run inference with the best trained model
#
# **Prerequisites**: `uv run python prepare.py` and at least one `uv run python train.py` run.

# %%
import json, random, sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image
import albumentations as A
from albumentations.pytorch import ToTensorV2

sys.path.insert(0, '.')

DATA_DIR   = Path('data')
IMAGES_DIR = DATA_DIR / 'images'
MASKS_DIR  = DATA_DIR / 'masks'
MODEL_PATH = Path('best_model_ResNet34UNet.pth')
INFER_SIZE = 384

print('data/ exists:        ', DATA_DIR.exists())
print('best_model.pth exists:', MODEL_PATH.exists())
# Out:
# data/ exists:         True
# best_model.pth exists: True

# %% [markdown]
# ## 1. Dataset overview

# %%
print(json.dumps(json.loads((DATA_DIR/'meta.json').read_text()), indent=2))
train_stems = (DATA_DIR/'train.txt').read_text().splitlines()
val_stems   = (DATA_DIR/'val.txt').read_text().splitlines()
print(f'\nTrain: {len(train_stems)}   Val: {len(val_stems)}')
# Out:
# {
#   "image_size": 512,
#   "train_count": 1275,
#   "val_count": 225,
#   "litter_pixel_fraction_sample": 0.0503,
#   "pos_weight_suggestion": 18.89
# }
#
# Train: 1275   Val: 225

# %% [markdown]
# ## 2. Sample images + masks

# %%
def show_samples(stems, n=8, title='Samples'):
    chosen = random.sample(stems, min(n, len(stems)))
    fig, axes = plt.subplots(2, len(chosen), figsize=(len(chosen)*2.5, 5))
    fig.suptitle(title, fontsize=13)
    for col, stem in enumerate(chosen):
        img  = Image.open(IMAGES_DIR/f'{stem}.jpg')
        mask = np.array(Image.open(MASKS_DIR/f'{stem}.png')) > 127
        axes[0,col].imshow(img); axes[0,col].axis('off')
        axes[0,col].set_title(stem, fontsize=7)
        overlay = np.array(img).copy().astype(float)
        overlay[mask] = (overlay[mask]*0.4 + np.array([255,80,0])*0.6).clip(0,255)
        axes[1,col].imshow(overlay.astype(np.uint8)); axes[1,col].axis('off')
        axes[1,col].set_title(f'{mask.mean():.1%} litter', fontsize=7)
    plt.tight_layout(); plt.show()

show_samples(train_stems, title='Training samples')
show_samples(val_stems,   title='Validation samples')

# %% [markdown]
# ## 3. Mask statistics

# %%
fracs = np.array([
    (np.array(Image.open(MASKS_DIR/f'{s}.png')) > 127).mean()
    for s in (train_stems + val_stems)
])
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].hist(fracs, bins=50, edgecolor='black')
axes[0].set(xlabel='Litter pixel fraction', ylabel='Count',
            title='Distribution of litter coverage per image')
axes[1].hist(fracs, bins=50, cumulative=True, density=True, edgecolor='black')
axes[1].set(xlabel='Litter pixel fraction', ylabel='Cumulative density', title='CDF')
plt.tight_layout(); plt.show()
print(f'Mean: {fracs.mean():.3%}  Median: {np.median(fracs):.3%}  '
      f'Empty: {(fracs==0).sum()}  >50%: {(fracs>0.5).sum()}')
# Out:
# Mean: 4.882%  Median: 1.304%  Empty: 0  >50%: 9

# %% [markdown]
# ## 4. MLflow experiment history

# %%
import mlflow, pandas as pd

client = mlflow.MlflowClient()
exp = client.get_experiment_by_name('litter-segmentation')
if exp is None:
    print('No experiment yet — run train.py first.')
else:
    runs = client.search_runs(
        experiment_ids=[exp.experiment_id],
        filter_string="attributes.status = 'FINISHED'",
        order_by=['metrics.best_val_iou DESC']
    )
    df = pd.DataFrame([{
        'run_name':     r.data.tags.get('mlflow.runName', r.info.run_id[:8]),
        'best_val_iou': r.data.metrics.get('best_val_iou', float('nan')),
        'elapsed_min':  round(r.data.metrics.get('elapsed_s', 0)/60, 1),
        'lr':           r.data.params.get('lr', '?'),
        'batch_size':   r.data.params.get('batch_size', '?'),
        'encoder':      r.data.params.get('encoder_channels', '?'),
    } for r in runs])
    display(df.style.highlight_max(subset=['best_val_iou'], color='lightgreen')
              .format({'best_val_iou': '{:.4f}'}))
# Out:
# <style type="text/css">
# #T_2c6b2_row0_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c6b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c6b2_level0_col0" class="col_heading level0 col0" >run_name</th>
#       <th id="T_2c6b2_level0_col1" class="col_heading level0 col1" >best_val_iou</th>
#       <th id="T_2c6b2_level0_col2" class="col_heading level0 col2" >elapsed_min</th>
#       <th id="T_2c6b2_level0_col3" class="col_heading level0 col3" >lr</th>
#       <th id="T_2c6b2_level0_col4" class="col_heading level0 col4" >batch_size</th>
#       <th id="T_2c6b2_level0_col5" class="col_heading level0 col5" >encoder</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c6b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c6b2_row0_col0" class="data row0 col0" >resnet34-90min</td>
#       <td id="T_2c6b2_row0_col1" class="data row0 col1" >0.6738</td>
#       <td id="T_2c6b2_row0_col2" class="data row0 col2" >89.500000</td>
#       <td id="T_2c6b2_row0_col3" class="data row0 col3" >0.0008</td>
#       <td id="T_2c6b2_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_2c6b2_row0_col5" class="data row0 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c6b2_row1_col0" class="data row1 col0" >efficientnetb4-90min</td>
#       <td id="T_2c6b2_row1_col1" class="data row1 col1" >0.6355</td>
#       <td id="T_2c6b2_row1_col2" class="data row1 col2" >89.900000</td>
#       <td id="T_2c6b2_row1_col3" class="data row1 col3" >0.0008</td>
#       <td id="T_2c6b2_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_2c6b2_row1_col5" class="data row1 col5" >EfficientNetB4-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c6b2_row2_col0" class="data row2 col0" >b4l2-smooth-0p005</td>
#       <td id="T_2c6b2_row2_col1" class="data row2 col1" >0.6323</td>
#       <td id="T_2c6b2_row2_col2" class="data row2 col2" >44.300000</td>
#       <td id="T_2c6b2_row2_col3" class="data row2 col3" >0.001</td>
#       <td id="T_2c6b2_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_2c6b2_row2_col5" class="data row2 col5" >EfficientNetB4-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c6b2_row3_col0" class="data row3 col0" >resnet34-smooth01-no-vflip</td>
#       <td id="T_2c6b2_row3_col1" class="data row3 col1" >0.6241</td>
#       <td id="T_2c6b2_row3_col2" class="data row3 col2" >19.800000</td>
#       <td id="T_2c6b2_row3_col3" class="data row3 col3" >0.0008</td>
#       <td id="T_2c6b2_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_2c6b2_row3_col5" class="data row3 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c6b2_row4_col0" class="data row4 col0" >b4l2-lr-1p5e-3</td>
#       <td id="T_2c6b2_row4_col1" class="data row4 col1" >0.6166</td>
#       <td id="T_2c6b2_row4_col2" class="data row4 col2" >44.300000</td>
#       <td id="T_2c6b2_row4_col3" class="data row4 col3" >0.0015</td>
#       <td id="T_2c6b2_row4_col4" class="data row4 col4" >8</td>
#       <td id="T_2c6b2_row4_col5" class="data row4 col5" >EfficientNetB4-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c6b2_row5_col0" class="data row5 col0" >b4-crop320-lr-1e-3</td>
#       <td id="T_2c6b2_row5_col1" class="data row5 col1" >0.6165</td>
#       <td id="T_2c6b2_row5_col2" class="data row5 col2" >44.400000</td>
#       <td id="T_2c6b2_row5_col3" class="data row5 col3" >0.001</td>
#       <td id="T_2c6b2_row5_col4" class="data row5 col4" >8</td>
#       <td id="T_2c6b2_row5_col5" class="data row5 col5" >EfficientNetB4-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c6b2_row6_col0" class="data row6 col0" >resnet34-label-smooth-0p01</td>
#       <td id="T_2c6b2_row6_col1" class="data row6 col1" >0.6125</td>
#       <td id="T_2c6b2_row6_col2" class="data row6 col2" >19.800000</td>
#       <td id="T_2c6b2_row6_col3" class="data row6 col3" >0.0008</td>
#       <td id="T_2c6b2_row6_col4" class="data row6 col4" >8</td>
#       <td id="T_2c6b2_row6_col5" class="data row6 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c6b2_row7_col0" class="data row7 col0" >resnet34-smooth01-grad-clip-0p5</td>
#       <td id="T_2c6b2_row7_col1" class="data row7 col1" >0.6115</td>
#       <td id="T_2c6b2_row7_col2" class="data row7 col2" >19.800000</td>
#       <td id="T_2c6b2_row7_col3" class="data row7 col3" >0.0008</td>
#       <td id="T_2c6b2_row7_col4" class="data row7 col4" >8</td>
#       <td id="T_2c6b2_row7_col5" class="data row7 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c6b2_row8_col0" class="data row8 col0" >resnet34-smooth01-no-gaussnoise</td>
#       <td id="T_2c6b2_row8_col1" class="data row8 col1" >0.6102</td>
#       <td id="T_2c6b2_row8_col2" class="data row8 col2" >19.800000</td>
#       <td id="T_2c6b2_row8_col3" class="data row8 col3" >0.0008</td>
#       <td id="T_2c6b2_row8_col4" class="data row8 col4" >8</td>
#       <td id="T_2c6b2_row8_col5" class="data row8 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c6b2_row9_col0" class="data row9 col0" >resnet34-smooth01-no-vflip-lr-7e-4</td>
#       <td id="T_2c6b2_row9_col1" class="data row9 col1" >0.6080</td>
#       <td id="T_2c6b2_row9_col2" class="data row9 col2" >19.800000</td>
#       <td id="T_2c6b2_row9_col3" class="data row9 col3" >0.0007</td>
#       <td id="T_2c6b2_row9_col4" class="data row9 col4" >8</td>
#       <td id="T_2c6b2_row9_col5" class="data row9 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c6b2_row10_col0" class="data row10 col0" >b4l2-no-gaussnoise</td>
#       <td id="T_2c6b2_row10_col1" class="data row10 col1" >0.6078</td>
#       <td id="T_2c6b2_row10_col2" class="data row10 col2" >44.300000</td>
#       <td id="T_2c6b2_row10_col3" class="data row10 col3" >0.001</td>
#       <td id="T_2c6b2_row10_col4" class="data row10 col4" >8</td>
#       <td id="T_2c6b2_row10_col5" class="data row10 col5" >EfficientNetB4-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c6b2_row11_col0" class="data row11 col0" >resnet34-smooth01-no-vflip-small-rotate</td>
#       <td id="T_2c6b2_row11_col1" class="data row11 col1" >0.6075</td>
#       <td id="T_2c6b2_row11_col2" class="data row11 col2" >19.800000</td>
#       <td id="T_2c6b2_row11_col3" class="data row11 col3" >0.0008</td>
#       <td id="T_2c6b2_row11_col4" class="data row11 col4" >8</td>
#       <td id="T_2c6b2_row11_col5" class="data row11 col5" >ResNet34-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2c6b2_row12_col0" class="data row12 col0" >b4l2-lr-1p2e-3</td>
#       <td id="T_2c6b2_row12_col1" class="data row12 col1" >0.6029</td>
#       <td id="T_2c6b2_row12_col2" class="data row12 col2" >44.800000</td>
#       <td id="T_2c6b2_row12_col3" class="data row12 col3" >0.0012</td>
#       <td id="T_2c6b2_row12_col4" class="data row12 col4" >8</td>
#       <td id="T_2c6b2_row12_col5" class="data row12 col5" >EfficientNetB4-pretrained</td>
#     </tr>
#     <tr>
#       <th id="T_2c6b2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2c6b2_row13_col0" class="data row13 col0" >resnet34-label-smooth-0p02</td>
#       <td id="T_2c6b2_row13_col1" class="data row13 col1" >0.6016</td>

# %%
# Bar chart of best val_iou per run
if exp:
    run_bests = sorted(
        [(r.data.metrics.get('best_val_iou', 0),
          r.data.tags.get('mlflow.runName', r.info.run_id[:8]))
         for r in runs if r.data.metrics.get('best_val_iou') is not None]
    )
    vals  = [x[0] for x in run_bests]
    names = [x[1] for x in run_bests]
    best  = max(vals)
    colours = ['tomato' if v == best else 'steelblue' for v in vals]
    fig, ax = plt.subplots(figsize=(10, max(4, len(names)*0.32)))
    ax.barh(names, vals, color=colours)
    ax.axvline(0.65, color='green', linestyle='--', alpha=0.7, label='target 0.65')
    ax.set(xlabel='best_val_iou', title='Best val_iou per run (red = best)')
    ax.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 5. Load best model

# %%
from train import *

def get_device():
    if torch.cuda.is_available():         return torch.device("cuda")
    if torch.backends.mps.is_available(): return torch.device("mps")
    return torch.device("cpu")

device = get_device()
model  = None

# ── Choose which model to load ─────────────────────────────────────────
# CHECKPOINT = "best_model.pth"           # overall best  (ResNet34, iou=0.6738)
# CHECKPOINT = "best_resnet34.pth"        # ResNet34       (iou=0.6738)
# CHECKPOINT = "best_efficientnetb4.pth" # EfficientNet-B4 (iou=0.6323)
CHECKPOINT  = "best_model.pth"
MODEL_CLASS = ResNet34UNet       # match to checkpoint above
# MODEL_CLASS = EfficientNetB4UNet

p = Path(CHECKPOINT)
if p.exists():
    model = MODEL_CLASS(dropout=DROPOUT).to(device)
    model.load_state_dict(torch.load(p, map_location=device))
    model.eval()
    n = sum(par.numel() for par in model.parameters())
    print(f"Loaded {CHECKPOINT} ({MODEL_CLASS.__name__}) on {device}  ({n:,} params)")
else:
    print(f"{CHECKPOINT} not found")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18408\3505901433.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(p, map_location=device))
# Loaded best_model.pth (ResNet34UNet) on cpu  (24,349,441 params)

# %% [markdown]
# ## 6. Inference helpers

# %%
infer_tf = A.Compose([
    A.Resize(INFER_SIZE, INFER_SIZE),
    A.Normalize(mean=(0.485,0.456,0.406), std=(0.229,0.224,0.225)),
    ToTensorV2(),
])

def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()
        if 'log_time' in kw:
            name = kw.get('log_name', method.__name__.upper())
            kw['log_time'][name] = int((te - ts) * 1000)
        else:
            print('%r  %2.2f ms' % \
                  (method.__name__, (te - ts) * 1000))
        return result
    return timed

@timeit
def predict(src, threshold=0.5):
    """src = file path (str/Path) or PIL Image."""
    assert model is not None, 'Load a model first'
    img = np.array((Image.open(src) if isinstance(src,(str,Path)) else src).convert('RGB'))
    t = infer_tf(image=img)['image'].unsqueeze(0).to(device)
    with torch.no_grad():
        prob = torch.sigmoid(model(t)).squeeze().cpu().numpy()
    return img, prob, (prob > threshold).astype(np.uint8)

def show_prediction(src, threshold=0.5, gt_mask_path=None):
    img, prob, pred = predict(src, threshold)
    disp = np.array(Image.fromarray(img).resize((INFER_SIZE, INFER_SIZE)))
    ncols = 4 if gt_mask_path else 3
    fig, axes = plt.subplots(1, ncols, figsize=(ncols*4, 4))
    axes[0].imshow(disp);  axes[0].set_title('Input');          axes[0].axis('off')
    axes[1].imshow(prob, cmap='hot', vmin=0, vmax=1)
    axes[1].set_title('Probability'); axes[1].axis('off')
    ov = disp.copy().astype(float)
    ov[pred.astype(bool)] = (ov[pred.astype(bool)]*0.4 + np.array([255,80,0])*0.6).clip(0,255)
    axes[2].imshow(ov.astype(np.uint8)); axes[2].set_title('Prediction'); axes[2].axis('off')
    if gt_mask_path:
        gt = (np.array(Image.open(gt_mask_path).resize(
            (INFER_SIZE,INFER_SIZE), Image.NEAREST)) > 127).astype(np.uint8)
        axes[3].imshow(gt, cmap='gray'); axes[3].set_title('Ground truth'); axes[3].axis('off')
        inter = (pred*gt).sum(); union = ((pred+gt)>0).sum()
        fig.suptitle(f'IoU = {inter/max(union,1):.4f}', fontsize=12)
    plt.tight_layout(); plt.show()

print('predict() and show_prediction() ready')
# Out:
# predict() and show_prediction() ready

# %% [markdown]
# ## 7. Predictions on validation samples

# %%
TEST_THRESHOLD = 0.7

if model is not None:
    for stem in random.sample(val_stems, min(6, len(val_stems))):
        show_prediction(IMAGES_DIR/f'{stem}.jpg',
                        threshold=TEST_THRESHOLD,
                        gt_mask_path=MASKS_DIR/f'{stem}.png')
# Out:
# 'predict'  739.66 ms
# 'predict'  522.90 ms
# 'predict'  475.01 ms
# 'predict'  456.61 ms
# 'predict'  500.26 ms
# 'predict'  447.33 ms

# %% [markdown]
# ## 8. Full validation IoU

# %%
if model is not None:
    ious = []
    for stem in val_stems:
        _, _, pred = predict(IMAGES_DIR/f'{stem}.jpg', threshold=TEST_THRESHOLD)
        gt = (np.array(Image.open(MASKS_DIR/f'{stem}.png').resize(
            (INFER_SIZE,INFER_SIZE), Image.NEAREST)) > 127).astype(np.uint8)
        ious.append((pred*gt).sum() / max(((pred+gt)>0).sum(), 1))
    ious = np.array(ious)
    
    print(f'mean={ious.mean():.4f}  median={np.median(ious):.4f}  '
          f'min={ious.min():.4f}  max={ious.max():.4f}')
    
    plt.figure(figsize=(8,4))
    plt.hist(ious, bins=30, edgecolor='black')
    plt.axvline(ious.mean(), color='red', linestyle='--', label=f'mean={ious.mean():.3f}')
    plt.xlabel('IoU'); plt.ylabel('Count')
    plt.title('Per-image IoU on validation set')
    plt.legend(); plt.tight_layout(); plt.show()
# Out:
# 'predict'  1779.15 ms
# 'predict'  587.71 ms
# 'predict'  480.91 ms
# 'predict'  1354.07 ms
# 'predict'  1197.72 ms
# 'predict'  1054.62 ms
# 'predict'  567.76 ms
# 'predict'  559.07 ms
# 'predict'  801.05 ms
# 'predict'  606.74 ms
# 'predict'  1021.81 ms
# 'predict'  1559.08 ms
# 'predict'  611.32 ms
# 'predict'  805.13 ms
# 'predict'  540.41 ms
# 'predict'  466.44 ms
# 'predict'  584.44 ms
# 'predict'  385.07 ms
# 'predict'  525.54 ms
# 'predict'  458.40 ms
# 'predict'  579.86 ms
# 'predict'  541.29 ms
# 'predict'  425.62 ms
# 'predict'  440.98 ms
# 'predict'  417.16 ms
# 'predict'  422.80 ms
# 'predict'  417.07 ms
# 'predict'  550.28 ms
# 'predict'  759.03 ms
# 'predict'  642.34 ms
# 'predict'  620.81 ms
# 'predict'  691.55 ms
# 'predict'  454.20 ms
# 'predict'  396.18 ms
# 'predict'  603.19 ms
# 'predict'  616.76 ms
# 'predict'  546.92 ms
# 'predict'  615.76 ms
# 'predict'  585.77 ms
# 'predict'  413.92 ms
# 'predict'  400.39 ms
# 'predict'  563.96 ms
# 'predict'  603.09 ms
# 'predict'  743.41 ms
# 'predict'  617.22 ms
# 'predict'  466.29 ms
# 'predict'  393.78 ms
# 'predict'  552.61 ms
# 'predict'  555.10 ms
# 'predict'  600.42 ms
# 'predict'  609.40 ms
# 'predict'  619.32 ms
# 'predict'  389.87 ms
# 'predict'  389.58 ms
# 'predict'  583.86 ms
# 'predict'  659.67 ms
# 'predict'  594.09 ms
# 'predict'  543.45 ms
# 'predict'  547.70 ms
# 'predict'  438.39 ms
# 'predict'  672.00 ms
# 'predict'  645.66 ms
# 'predict'  575.17 ms
# 'predict'  717.30 ms
# 'predict'  549.27 ms
# 'predict'  448.54 ms
# 'predict'  431.67 ms
# 'predict'  521.30 ms
# 'predict'  509.57 ms
# 'predict'  658.37 ms
# 'predict'  596.04 ms
# 'predict'  648.61 ms
# 'predict'  439.08 ms
# 'predict'  457.36 ms
# 'predict'  608.24 ms
# 'predict'  694.86 ms
# 'predict'  574.06 ms
# 'predict'  458.19 ms
# 'predict'  536.84 ms
# 'predict'  435.25 ms
# 'predict'  452.44 ms
# 'predict'  474.99 ms
# 'predict'  541.34 ms
# 'predict'  652.96 ms
# 'predict'  496.56 ms
# 'predict'  501.28 ms
# 'predict'  484.34 ms
# 'predict'  482.92 ms
# 'predict'  487.59 ms
# 'predict'  469.61 ms
# 'predict'  634.55 ms
# 'predict'  492.13 ms
# 'predict'  549.52 ms
# 'predict'  529.49 ms
# 'predict'  449.39 ms
# 'predict'  434.30 ms
# 'predict'  456.16 ms
# 'predict'  558.86 ms
# 'predict'  490.89 ms
# 'predict'  425.94 ms
# 'predict'  445.36 ms
# 'predict'  403.99 ms
# 'predict'  520.13 ms
# 'predict'  681.66 ms
# 'predict'  610.04 ms
# 'predict'  606.51 ms
# 'predict'  588.57 ms
# 'predict'  388.72 ms
# 'predict'  450.10 ms
# 'predict'  525.47 ms
# 'predict'  690.81 ms
# 'predict'  605.90 ms
# 'predict'  643.16 ms
# 'predict'  443.08 ms
# 'predict'  387.46 ms
# 'predict'  510.71 ms
# 'predict'  586.10 ms
# 'predict'  795.84 ms
# 'predict'  615.69 ms
# 'predict'  524.79 ms
# 'predict'  382.26 ms
# 'predict'  458.62 ms
# 'predict'  566.66 ms
# 'predict'  730.85 ms
# 'predict'  594.93 ms
# 'predict'  610.47 ms
# 'predict'  385.62 ms
# 'predict'  397.38 ms
# 'predict'  556.82 ms
# 'predict'  544.11 ms
# 'predict'  652.74 ms
# 'predict'  619.21 ms
# 'predict'  537.38 ms
# 'predict'  395.79 ms
# 'predict'  510.43 ms
# 'predict'  519.94 ms
# 'predict'  605.66 ms
# 'predict'  715.00 ms
# 'predict'  599.23 ms
# 'predict'  413.33 ms
# 'predict'  377.89 ms
# 'predict'  559.93 ms
# 'predict'  560.57 ms
# 'predict'  712.59 ms
# 'predict'  620.46 ms
# 'predict'  519.86 ms
# 'predict'  392.27 ms
# 'predict'  501.15 ms
# 'predict'  667.47 ms
# 'predict'  652.51 ms
# 'predict'  597.41 ms
# 'predict'  567.28 ms
# 'predict'  385.75 ms
# 'predict'  423.65 ms
# 'predict'  538.10 ms
# 'predict'  667.37 ms
# 'predict'  624.14 ms
# 'predict'  606.93 ms
# 'predict'  479.73 ms
# 'predict'  381.45 ms
# 'predict'  510.51 ms
# 'predict'  622.07 ms
# 'predict'  609.95 ms
# 'predict'  622.01 ms
# 'predict'  596.44 ms
# 'predict'  393.02 ms
# 'predict'  410.06 ms
# 'predict'  523.55 ms
# 'predict'  623.73 ms
# 'predict'  709.58 ms
# 'predict'  590.28 ms
# 'predict'  484.11 ms
# 'predict'  380.77 ms
# 'predict'  520.80 ms
# 'predict'  634.96 ms
# 'predict'  606.62 ms
# 'predict'  622.02 ms
# 'predict'  577.05 ms
# 'predict'  429.21 ms
# 'predict'  424.09 ms
# 'predict'  524.21 ms
# 'predict'  705.69 ms
# 'predict'  609.39 ms
# 'predict'  620.81 ms
# 'predict'  509.62 ms
# 'predict'  523.67 ms
# 'predict'  619.77 ms
# 'predict'  636.58 ms
# 'predict'  781.08 ms
# 'predict'  753.82 ms
# 'predict'  538.94 ms
# 'predict'  399.35 ms
# 'predict'  392.04 ms
# 'predict'  621.62 ms
# 'predict'  852.27 ms
# 'predict'  459.76 ms
# 'predict'  485.07 ms
# 'predict'  603.22 ms
# 'predict'  440.70 ms
# 'predict'  443.74 ms
# 'predict'  450.68 ms
# 'predict'  450.39 ms
# 'predict'  446.34 ms
# 'predict'  408.35 ms
# 'predict'  407.75 ms
# 'predict'  504.71 ms
# 'predict'  380.43 ms
# 'predict'  386.22 ms
# 'predict'  931.73 ms
# 'predict'  851.45 ms
# 'predict'  482.23 ms
# 'predict'  446.61 ms
# 'predict'  458.69 ms
# 'predict'  397.11 ms
# 'predict'  417.73 ms
# 'predict'  415.79 ms
# 'predict'  513.97 ms
# 'predict'  428.50 ms
# 'predict'  423.04 ms
# 'predict'  408.14 ms
# 'predict'  451.49 ms
# 'predict'  396.25 ms
# 'predict'  381.34 ms
# 'predict'  451.15 ms
# 'predict'  566.99 ms
# mean=0.6067  median=0.6644  min=0.0000  max=0.9829

# %% [markdown]
# ## 9. Worst predictions (lowest IoU)

# %%
if model is not None and 'ious' in dir():
    worst = sorted(zip(ious, val_stems))[:4]
    print('Worst 4 predictions:')
    for iou_val, stem in worst:
        print(f'  {stem}  iou={iou_val:.4f}')
        show_prediction(IMAGES_DIR/f'{stem}.jpg',
                        threshold=TEST_THRESHOLD,
                        gt_mask_path=MASKS_DIR/f'{stem}.png')
# Out:
# Worst 4 predictions:
#   000057  iou=0.0000
# 'predict'  478.24 ms
#   000111  iou=0.0000
# 'predict'  441.95 ms
#   000181  iou=0.0000
# 'predict'  440.36 ms
#   000184  iou=0.0000
# 'predict'  412.69 ms

# %% [markdown]
# ## 10. Inference on a custom image
#
# Set `CUSTOM_IMAGE` to any file path and run.

# %%
CUSTOM_IMAGE = './image3.jpeg'
show_prediction(CUSTOM_IMAGE, threshold=TEST_THRESHOLD)
# Out:
# 'predict'  565.94 ms
